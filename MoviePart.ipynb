# %%
from google.colab import drive
drive.mount('/content/drive2', force_remount=True)
driveHome = "/content/drive2/MyDrive/MasterThesis"


def flushDrive():
    drive.flush_and_unmount()
    drive.mount('/content/drive2')
# Out:
# Mounted at /content/drive2

# %%
# %%capture
# !pip install youtube-dl moviepy
# !pip install git+https://github.com/TahaAnwar/pafy.git#egg=pafy

# !apt install --allow-change-held-packages libcudnn8=8.1.0.77-1+cuda11.2

# %%
import os
from os.path import basename, join
import cv2
import pafy
import math
import random
import numpy as np
import datetime as dt
import tensorflow as tf
from collections import deque
import matplotlib.pyplot as plt
import shutil
from pathlib import Path
import re
import gc

from moviepy.editor import *
# %matplotlib inline

from sklearn.model_selection import train_test_split

from tensorflow import keras
from tensorflow.keras.layers import *
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.utils import plot_model
# Out:
# Imageio: 'ffmpeg-linux64-v3.3.1' was not found on your computer; downloading it now.
# Try 1. Download from https://github.com/imageio/imageio-binaries/raw/master/ffmpeg/ffmpeg-linux64-v3.3.1 (43.8 MB)
# 45929032/45929032 bytes (100.0%)
#   Done
# File saved as /root/.imageio/ffmpeg/ffmpeg-linux64-v3.3.1.

# %%
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
seed_constant = 27
np.random.seed(seed_constant)
random.seed(seed_constant)
tf.random.set_seed(seed_constant)

IMAGE_HEIGHT , IMAGE_WIDTH = 224, 224
SEQUENCE_LENGTH = 20
DATASET_DIR = "UCF101"

CLASSES_LIST = [
           "BlowingCandles",
           "Billiards", 
           "BrushingTeeth", 
           "CuttingInKitchen",
           "Mixing",
           "MoppingFloor", 
           "ShavingBeard", 
           "Swing",
           "Typing",
           "WallPushups",
]

# %%
if (not os.path.exists(DATASET_DIR)):
    Path(DATASET_DIR).mkdir(parents=True,exist_ok=True)
    root = os.path.join(driveHome,"UCF-101")
    for actionType in os.listdir(root):
        newActionPath=join(DATASET_DIR, actionType)
        Path(newActionPath).mkdir(exist_ok=True)
        moviesPath=join(root, actionType)
        lenList=len(os.listdir(moviesPath))
        print(f"{actionType} : {lenList}")
        counter = 0
        for movie in os.scandir(moviesPath):
            shutil.copyfile(movie.path, join(newActionPath, movie.name))
            counter += 1
            if counter >= lenList*1/2:
                break
# Out:
# BrushingTeeth : 131
# CuttingInKitchen : 110
# MoppingFloor : 110
# ShavingBeard : 161
# Typing : 136
# WallPushups : 130
# Billiards : 150
# Mixing : 136
# Swing : 131
# BlowingCandles : 109

# %%
CHOSEN_MODELS={
    "InceptionV3": [
                    "/content/drive2/MyDrive/MasterThesis/taught-smart/-with-transfer/Augmented/0.1/greyscale/InceptionV3Model/250/model_ex-011_loss-0.740166_acc-0.732337.h5",
                    "/content/drive2/MyDrive/MasterThesis/taught-smart/-with-transfer/Augmented/0.1/mix-net/InceptionV3Model/2000/model_ex-008_loss-0.295730_acc-0.901495.h5",
                    ],
    "MobileNetV2" : [
                    "/content/drive2/MyDrive/MasterThesis/taught-smart/-with-transfer/Augmented/0.1/brightness/MobileNetV2Model/250/model_ex-029_loss-1.070119_acc-0.591033.h5",
                     "/content/drive2/MyDrive/MasterThesis/taught-smart/-with-transfer/Augmented/0.333/mix-weak/MobileNetV2Model/3000/model_ex-020_loss-0.561358_acc-0.828635.h5",
                    ],
    "EfficientNetV2B0" : [
                        "/content/drive2/MyDrive/MasterThesis/taught-smart/-with-transfer/Augmented/0.1/gaussian-mix/EfficientNetV2B0Model/250/model_ex-011_loss-0.749594_acc-0.729959.h5",
                        "/content/drive2/MyDrive/MasterThesis/taught-smart/-with-transfer/Augmented/0.1/crop/EfficientNetV2B0Model/2000/model_ex-003_loss-0.179559_acc-0.958050.h5",
                        ], 
    }

# %%
def frames_extraction(video_path, normalize):
    frames_list = []
    video_reader = cv2.VideoCapture(video_path)
    video_frames_count = int(video_reader.get(cv2.CAP_PROP_FRAME_COUNT))
    skip_frames_window = max(int(video_frames_count/SEQUENCE_LENGTH), 1)
    for frame_counter in range(SEQUENCE_LENGTH):
        video_reader.set(cv2.CAP_PROP_POS_FRAMES, frame_counter * skip_frames_window)
        success, frame = video_reader.read() 
        if not success:
            break
        resized_frame = cv2.resize(frame, (IMAGE_HEIGHT, IMAGE_WIDTH))
        normalized_frame = resized_frame
        if normalize:
            normalized_frame = resized_frame / 255
        frames_list.append(normalized_frame)
    video_reader.release()

    return frames_list

# %%
def create_dataset(normalize):
    features = []
    labels = []
    video_files_paths = []
    for class_index, class_name in enumerate(CLASSES_LIST):
        print(f'Extracting Data of Class: {class_name}')
        files_list = os.listdir(os.path.join(DATASET_DIR, class_name))
        for file_name in files_list:
            video_file_path = os.path.join(DATASET_DIR, class_name, file_name)
            frames = frames_extraction(video_file_path, normalize)
            if len(frames) == SEQUENCE_LENGTH:
                features.append(frames)
                labels.append(class_index)
                video_files_paths.append(video_file_path)

    features = np.asarray(features)
    labels = np.array(labels)  
    
    return features, labels, video_files_paths

# %%
def prepare_data(normalize):
    features, labels, video_files_paths = create_dataset(normalize)
    one_hot_encoded_labels = to_categorical(labels)
    features_train, features_test, labels_train, labels_test = train_test_split(features, one_hot_encoded_labels,
                                                                            test_size = 0.25, shuffle = True,
                                                                            random_state = seed_constant)
    
    return features_train, features_test, labels_train, labels_test

# %%
def create_LRCN_model(path_to_model, rnn):
    base_model=keras.models.load_model(path_to_model)
    model = Sequential()
    model.add(TimeDistributed(base_model, input_shape=(SEQUENCE_LENGTH, IMAGE_HEIGHT, IMAGE_WIDTH, 3)))
    model.layers[0].trainable=False
    if rnn == "GRU":
        model.add(tf.keras.layers.GRU(64))
    else:
        model.add(tf.keras.layers.LSTM(64))
    model.add(tf.keras.layers.Dense(len(CLASSES_LIST), activation='softmax', use_bias=True))

    return model

# %%
def save(LRCN_model, modelName, number, features_test, labels_test, rnn_type):
    model_evaluation_history = LRCN_model.evaluate(features_test, labels_test)
    model_evaluation_loss, model_evaluation_accuracy = model_evaluation_history
    date_time_format = '%Y_%m_%d__%H_%M_%S'
    current_date_time_dt = dt.datetime.now()
    current_date_time_string = dt.datetime.strftime(current_date_time_dt, date_time_format)
    model_file_name = f'{driveHome}/UCF-SmartSplit/moviesModels/LRCN_model__{modelName}_{number}_{rnn_type}_Date_Time_{current_date_time_string}___Accuracy_{model_evaluation_accuracy}.h5'

    LRCN_model.save(model_file_name)

# %%
def train(LRCN_model, features_train, labels_train):
    early_stopping_callback = EarlyStopping(monitor = 'val_accuracy', patience = 10, restore_best_weights = True)
    LRCN_model.compile(loss = 'categorical_crossentropy', optimizer = 'Adam', metrics = ["accuracy"])
    LRCN_model_training_history = LRCN_model.fit(x = features_train, y = labels_train, epochs = 100, batch_size = 4,
                                                shuffle = True, validation_split = 0.2, callbacks = [early_stopping_callback])
    return LRCN_model

# %%
for modelName in CHOSEN_MODELS.keys():
    if modelName == "EfficientNetV2B0":
        features_train, features_test, labels_train, labels_test = prepare_data(False)
    else:
        features_train, features_test, labels_train, labels_test = prepare_data(True)

    for rnn_type in ["GRU", "LSTM"]:
        for idx, modelFullPath in enumerate(CHOSEN_MODELS[modelName]):
            kerasModel = create_LRCN_model(modelFullPath, rnn_type)
            print(modelName, rnn_type, idx)
            kerasModel = train(kerasModel, features_train, labels_train)
            save(kerasModel, modelName, idx, features_test, labels_test, rnn_type)
            flushDrive()
    
    del features_train
    gc.collect()
# Out:
# Extracting Data of Class: BlowingCandles
# Extracting Data of Class: Billiards
# Extracting Data of Class: BrushingTeeth
# Extracting Data of Class: CuttingInKitchen
# Extracting Data of Class: Mixing
# Extracting Data of Class: MoppingFloor
# Extracting Data of Class: ShavingBeard
# Extracting Data of Class: Swing
# Extracting Data of Class: Typing
# Extracting Data of Class: WallPushups
# InceptionV3 0
# Epoch 1/100
# 98/98 [==============================] - 25s 162ms/step - loss: 1.8729 - accuracy: 0.5612 - val_loss: 1.4234 - val_accuracy: 0.6327
# Epoch 2/100
# 98/98 [==============================] - 12s 125ms/step - loss: 0.9529 - accuracy: 0.7143 - val_loss: 0.8054 - val_accuracy: 0.7041
# Epoch 3/100
# 98/98 [==============================] - 12s 125ms/step - loss: 0.7074 - accuracy: 0.7270 - val_loss: 0.6515 - val_accuracy: 0.7143
# Epoch 4/100
# 98/98 [==============================] - 12s 125ms/step - loss: 0.5955 - accuracy: 0.7577 - val_loss: 0.5767 - val_accuracy: 0.8061
# Epoch 5/100
# 98/98 [==============================] - 12s 123ms/step - loss: 0.6213 - accuracy: 0.7628 - val_loss: 0.6281 - val_accuracy: 0.7551
# Epoch 6/100
# 98/98 [==============================] - 12s 123ms/step - loss: 0.5773 - accuracy: 0.7500 - val_loss: 0.6305 - val_accuracy: 0.7245
# Epoch 7/100
# 98/98 [==============================] - 12s 123ms/step - loss: 0.5526 - accuracy: 0.7730 - val_loss: 0.6174 - val_accuracy: 0.7857
# Epoch 8/100
# 98/98 [==============================] - 12s 123ms/step - loss: 0.5323 - accuracy: 0.7781 - val_loss: 0.5920 - val_accuracy: 0.7857
# Epoch 9/100
# 98/98 [==============================] - 12s 124ms/step - loss: 0.5142 - accuracy: 0.8061 - val_loss: 0.6544 - val_accuracy: 0.7143
# Epoch 10/100
# 98/98 [==============================] - 12s 123ms/step - loss: 0.5071 - accuracy: 0.8036 - val_loss: 0.6723 - val_accuracy: 0.7755
# Epoch 11/100
# 98/98 [==============================] - 12s 123ms/step - loss: 0.5127 - accuracy: 0.7832 - val_loss: 0.6144 - val_accuracy: 0.7449
# 98/98 [==============================] - 12s 123ms/step - loss: 0.1532 - accuracy: 0.9311 - val_loss: 0.1397 - val_accuracy: 0.9592
# Epoch 8/100
# 98/98 [==============================] - 12s 123ms/step - loss: 0.1345 - accuracy: 0.9566 - val_loss: 0.1467 - val_accuracy: 0.9286
# Epoch 9/100
# 98/98 [==============================] - 12s 124ms/step - loss: 0.1372 - accuracy: 0.9541 - val_loss: 0.1252 - val_accuracy: 0.9796
# Epoch 10/100
# 98/98 [==============================] - 12s 123ms/step - loss: 0.1250 - accuracy: 0.9566 - val_loss: 0.0955 - val_accuracy: 0.9694
# Epoch 11/100
# 98/98 [==============================] - 12s 124ms/step - loss: 0.1276 - accuracy: 0.9592 - val_loss: 0.1079 - val_accuracy: 0.9694
# Epoch 12/100
# 98/98 [==============================] - 12s 123ms/step - loss: 0.1231 - accuracy: 0.9566 - val_loss: 0.1082 - val_accuracy: 0.9694
# Epoch 13/100
# 98/98 [==============================] - 12s 123ms/step - loss: 0.1302 - accuracy: 0.9515 - val_loss: 0.1070 - val_accuracy: 0.9592
# Epoch 14/100
# 98/98 [==============================] - 12s 124ms/step - loss: 0.1241 - accuracy: 0.9592 - val_loss: 0.1037 - val_accuracy: 0.9694
# Epoch 15/100
# 98/98 [==============================] - 12s 123ms/step - loss: 0.1175 - accuracy: 0.9592 - val_loss: 0.1095 - val_accuracy: 0.9592
# Epoch 16/100
# 98/98 [==============================] - 12s 123ms/step - loss: 0.1134 - accuracy: 0.9617 - val_loss: 0.0931 - val_accuracy: 0.9694
# Epoch 17/100
# 98/98 [==============================] - 12s 124ms/step - loss: 0.1654 - accuracy: 0.9464 - val_loss: 0.1210 - val_accuracy: 0.9694
# Epoch 18/100
# 98/98 [==============================] - 12s 123ms/step - loss: 0.1526 - accuracy: 0.9515 - val_loss: 0.1161 - val_accuracy: 0.9592
# Epoch 19/100
# 98/98 [==============================] - 12s 125ms/step - loss: 0.1261 - accuracy: 0.9515 - val_loss: 0.1121 - val_accuracy: 0.9694
# 6/6 [==============================] - 4s 534ms/step - loss: 0.1068 - accuracy: 0.9695
# Mounted at /content/drive2
# Extracting Data of Class: BlowingCandles
# Extracting Data of Class: Billiards
# Extracting Data of Class: BrushingTeeth
# Extracting Data of Class: CuttingInKitchen
# Extracting Data of Class: Mixing
# Extracting Data of Class: MoppingFloor
# Extracting Data of Class: ShavingBeard
# Extracting Data of Class: Swing
# Extracting Data of Class: Typing
# Extracting Data of Class: WallPushups
# MobileNetV2 0
# Epoch 1/100
# 98/98 [==============================] - 15s 108ms/step - loss: 1.9242 - accuracy: 0.4872 - val_loss: 1.4842 - val_accuracy: 0.5408
# Epoch 2/100
# 98/98 [==============================] - 8s 82ms/step - loss: 1.1644 - accuracy: 0.6250 - val_loss: 1.0154 - val_accuracy: 0.6327
# Epoch 3/100
# 98/98 [==============================] - 8s 83ms/step - loss: 0.8679 - accuracy: 0.6913 - val_loss: 0.8232 - val_accuracy: 0.6735
# Epoch 4/100
# 98/98 [==============================] - 8s 82ms/step - loss: 0.7816 - accuracy: 0.7117 - val_loss: 0.7815 - val_accuracy: 0.6837
# Epoch 5/100
# 98/98 [==============================] - 8s 82ms/step - loss: 0.7546 - accuracy: 0.7219 - val_loss: 0.7571 - val_accuracy: 0.6837
# Epoch 6/100
# 98/98 [==============================] - 8s 82ms/step - loss: 0.6598 - accuracy: 0.7474 - val_loss: 0.7883 - val_accuracy: 0.6735
# Epoch 7/100
# 98/98 [==============================] - 8s 82ms/step - loss: 0.6599 - accuracy: 0.7474 - val_loss: 0.6655 - val_accuracy: 0.7653
# Epoch 8/100
# 98/98 [==============================] - 8s 81ms/step - loss: 0.6291 - accuracy: 0.7526 - val_loss: 0.7221 - val_accuracy: 0.7347
# Epoch 9/100
# 98/98 [==============================] - 8s 82ms/step - loss: 0.6050 - accuracy: 0.7704 - val_loss: 0.7629 - val_accuracy: 0.6224
# Epoch 10/100
# 98/98 [==============================] - 8s 81ms/step - loss: 0.6009 - accuracy: 0.7755 - val_loss: 0.7880 - val_accuracy: 0.7449
# Epoch 11/100
# 98/98 [==============================] - 8s 82ms/step - loss: 0.5598 - accuracy: 0.8087 - val_loss: 0.7952 - val_accuracy: 0.7143
# Epoch 12/100
# 98/98 [==============================] - 8s 82ms/step - loss: 0.5754 - accuracy: 0.7679 - val_loss: 0.6938 - val_accuracy: 0.7245
# Epoch 13/100
# 98/98 [==============================] - 8s 81ms/step - loss: 0.5729 - accuracy: 0.7832 - val_loss: 0.6835 - val_accuracy: 0.8061
# Epoch 14/100
# 98/98 [==============================] - 8s 82ms/step - loss: 0.5324 - accuracy: 0.7959 - val_loss: 0.6851 - val_accuracy: 0.7755
# Epoch 15/100
# 98/98 [==============================] - 8s 82ms/step - loss: 0.5191 - accuracy: 0.7959 - val_loss: 0.7491 - val_accuracy: 0.7449
# Epoch 16/100
# 98/98 [==============================] - 8s 81ms/step - loss: 0.5416 - accuracy: 0.7730 - val_loss: 0.7263 - val_accuracy: 0.7143
# Epoch 17/100
# 98/98 [==============================] - 8s 81ms/step - loss: 0.5234 - accuracy: 0.8010 - val_loss: 0.6741 - val_accuracy: 0.7143
# Epoch 18/100
# 98/98 [==============================] - 8s 82ms/step - loss: 0.5008 - accuracy: 0.7985 - val_loss: 0.6670 - val_accuracy: 0.7653
# Epoch 19/100
# 98/98 [==============================] - 8s 82ms/step - loss: 0.5638 - accuracy: 0.7806 - val_loss: 0.6311 - val_accuracy: 0.7551
# Epoch 20/100
# 98/98 [==============================] - 8s 82ms/step - loss: 0.5001 - accuracy: 0.8010 - val_loss: 0.8371 - val_accuracy: 0.7245
# Epoch 21/100
# 98/98 [==============================] - 8s 81ms/step - loss: 0.4889 - accuracy: 0.8163 - val_loss: 0.7754 - val_accuracy: 0.7959
# Epoch 22/100
# 98/98 [==============================] - 8s 81ms/step - loss: 0.4870 - accuracy: 0.8112 - val_loss: 0.7212 - val_accuracy: 0.7143
# Epoch 23/100
# 98/98 [==============================] - 8s 83ms/step - loss: 0.4882 - accuracy: 0.7985 - val_loss: 0.7768 - val_accuracy: 0.6939
# 6/6 [==============================] - 3s 377ms/step - loss: 0.6223 - accuracy: 0.7683
# Mounted at /content/drive2
# MobileNetV2 1
# Epoch 8/100
# 98/98 [==============================] - 8s 82ms/step - loss: 0.6443 - accuracy: 0.7730 - val_loss: 0.7637 - val_accuracy: 0.7449
# Epoch 9/100
# 98/98 [==============================] - 8s 82ms/step - loss: 0.6157 - accuracy: 0.7679 - val_loss: 0.7347 - val_accuracy: 0.7449
# Epoch 10/100
# 98/98 [==============================] - 8s 82ms/step - loss: 0.6069 - accuracy: 0.7755 - val_loss: 0.9242 - val_accuracy: 0.7245
# Epoch 11/100
# 98/98 [==============================] - 8s 82ms/step - loss: 0.5699 - accuracy: 0.7806 - val_loss: 0.7689 - val_accuracy: 0.7551
# Epoch 12/100
# 98/98 [==============================] - 8s 83ms/step - loss: 0.5714 - accuracy: 0.7908 - val_loss: 0.8093 - val_accuracy: 0.6837
# 6/6 [==============================] - 3s 373ms/step - loss: 0.8533 - accuracy: 0.6951
# Mounted at /content/drive2
# MobileNetV2 1
# Epoch 1/100
# 98/98 [==============================] - 14s 108ms/step - loss: 1.2776 - accuracy: 0.7985 - val_loss: 0.3927 - val_accuracy: 0.9796
# Epoch 2/100
# 98/98 [==============================] - 8s 81ms/step - loss: 0.2148 - accuracy: 0.9439 - val_loss: 0.2144 - val_accuracy: 0.9388
# Epoch 3/100
# 98/98 [==============================] - 8s 82ms/step - loss: 0.1638 - accuracy: 0.9541 - val_loss: 0.2666 - val_accuracy: 0.9184
# Epoch 4/100
# 98/98 [==============================] - 8s 81ms/step - loss: 0.1432 - accuracy: 0.9592 - val_loss: 0.1588 - val_accuracy: 0.9694
# Epoch 5/100
# 98/98 [==============================] - 8s 82ms/step - loss: 0.1263 - accuracy: 0.9668 - val_loss: 0.1921 - val_accuracy: 0.9388
# Epoch 6/100
# 98/98 [==============================] - 8s 82ms/step - loss: 0.1090 - accuracy: 0.9643 - val_loss: 0.2722 - val_accuracy: 0.8673
# Epoch 7/100
# 98/98 [==============================] - 8s 81ms/step - loss: 0.1525 - accuracy: 0.9541 - val_loss: 0.1698 - val_accuracy: 0.9388
# Epoch 8/100
# 98/98 [==============================] - 8s 81ms/step - loss: 0.1298 - accuracy: 0.9592 - val_loss: 0.1628 - val_accuracy: 0.9388
# Epoch 9/100
# 98/98 [==============================] - 8s 81ms/step - loss: 0.0959 - accuracy: 0.9668 - val_loss: 0.1779 - val_accuracy: 0.9694
# Epoch 10/100
# 98/98 [==============================] - 8s 82ms/step - loss: 0.1118 - accuracy: 0.9617 - val_loss: 0.1811 - val_accuracy: 0.9592
# Epoch 11/100
# 98/98 [==============================] - 8s 82ms/step - loss: 0.0803 - accuracy: 0.9694 - val_loss: 0.1824 - val_accuracy: 0.9592
# 6/6 [==============================] - 3s 374ms/step - loss: 0.3594 - accuracy: 0.9390
# Mounted at /content/drive2
# Extracting Data of Class: BlowingCandles
# Extracting Data of Class: Billiards
# Extracting Data of Class: BrushingTeeth
# Extracting Data of Class: CuttingInKitchen
# Extracting Data of Class: Mixing
# Extracting Data of Class: MoppingFloor
# Extracting Data of Class: ShavingBeard
# Extracting Data of Class: Swing
# Extracting Data of Class: Typing
# Extracting Data of Class: WallPushups
# EfficientNetV2B0 0
# Epoch 1/100
# 98/98 [==============================] - 19s 111ms/step - loss: 1.7829 - accuracy: 0.5612 - val_loss: 1.2983 - val_accuracy: 0.5000
# Epoch 2/100
# 98/98 [==============================] - 8s 81ms/step - loss: 0.8247 - accuracy: 0.7143 - val_loss: 0.8637 - val_accuracy: 0.6224
# Epoch 3/100
# 98/98 [==============================] - 8s 81ms/step - loss: 0.6236 - accuracy: 0.7449 - val_loss: 0.9034 - val_accuracy: 0.6327
# Epoch 4/100
# 98/98 [==============================] - 8s 81ms/step - loss: 0.5301 - accuracy: 0.7908 - val_loss: 0.7559 - val_accuracy: 0.7449
# Epoch 5/100
# 98/98 [==============================] - 8s 80ms/step - loss: 0.5191 - accuracy: 0.7628 - val_loss: 0.6777 - val_accuracy: 0.7143
# Epoch 6/100
# 98/98 [==============================] - 8s 81ms/step - loss: 0.4769 - accuracy: 0.8087 - val_loss: 0.8516 - val_accuracy: 0.6837
# Epoch 7/100
# 98/98 [==============================] - 8s 81ms/step - loss: 0.5207 - accuracy: 0.7959 - val_loss: 0.6369 - val_accuracy: 0.7959
# Epoch 8/100
# 98/98 [==============================] - 8s 80ms/step - loss: 0.4488 - accuracy: 0.8112 - val_loss: 0.6273 - val_accuracy: 0.7755
# Epoch 9/100
# 98/98 [==============================] - 8s 80ms/step - loss: 0.4249 - accuracy: 0.8367 - val_loss: 0.6102 - val_accuracy: 0.7347
# Epoch 10/100
# 98/98 [==============================] - 8s 80ms/step - loss: 0.4260 - accuracy: 0.8214 - val_loss: 0.6586 - val_accuracy: 0.7857
# Epoch 11/100
# 98/98 [==============================] - 8s 80ms/step - loss: 0.4021 - accuracy: 0.8367 - val_loss: 0.6315 - val_accuracy: 0.7551
# Epoch 12/100
# 98/98 [==============================] - 8s 80ms/step - loss: 0.4061 - accuracy: 0.8367 - val_loss: 0.6839 - val_accuracy: 0.7347
# Epoch 13/100
# 98/98 [==============================] - 8s 80ms/step - loss: 0.3765 - accuracy: 0.8393 - val_loss: 0.6963 - val_accuracy: 0.7857
# Epoch 14/100
# 98/98 [==============================] - 8s 80ms/step - loss: 0.3808 - accuracy: 0.8393 - val_loss: 0.6188 - val_accuracy: 0.7959
# Epoch 15/100
# 98/98 [==============================] - 8s 80ms/step - loss: 0.4159 - accuracy: 0.8469 - val_loss: 0.7719 - val_accuracy: 0.7041
# Epoch 16/100
# 98/98 [==============================] - 8s 80ms/step - loss: 0.4061 - accuracy: 0.8189 - val_loss: 0.6112 - val_accuracy: 0.7653
# Epoch 17/100
# 98/98 [==============================] - 8s 81ms/step - loss: 0.3627 - accuracy: 0.8520 - val_loss: 0.5479 - val_accuracy: 0.8061
# Epoch 18/100
# 98/98 [==============================] - 8s 80ms/step - loss: 0.3479 - accuracy: 0.8622 - val_loss: 0.6396 - val_accuracy: 0.7755
# Epoch 19/100
# 98/98 [==============================] - 8s 81ms/step - loss: 0.3547 - accuracy: 0.8367 - val_loss: 0.5967 - val_accuracy: 0.8163
# Epoch 20/100
# 98/98 [==============================] - 8s 81ms/step - loss: 0.3272 - accuracy: 0.8673 - val_loss: 0.5932 - val_accuracy: 0.8265
# Epoch 21/100
# 98/98 [==============================] - 8s 81ms/step - loss: 0.3370 - accuracy: 0.8622 - val_loss: 0.5822 - val_accuracy: 0.8265
# Epoch 22/100
# 98/98 [==============================] - 8s 81ms/step - loss: 0.3171 - accuracy: 0.8750 - val_loss: 0.6421 - val_accuracy: 0.7857
# Epoch 23/100
# 98/98 [==============================] - 8s 80ms/step - loss: 0.3474 - accuracy: 0.8597 - val_loss: 0.6193 - val_accuracy: 0.7857
# Epoch 24/100
# 98/98 [==============================] - 8s 80ms/step - loss: 0
100
# 98/98 [==============================] - 8s 80ms/step - loss: 0.5337 - accuracy: 0.8036 - val_loss: 0.7627 - val_accuracy: 0.6429
# Epoch 4/100
# 98/98 [==============================] - 8s 81ms/step - loss: 0.5355 - accuracy: 0.7985 - val_loss: 0.6113 - val_accuracy: 0.8061
# Epoch 5/100
# 98/98 [==============================] - 8s 81ms/step - loss: 0.4673 - accuracy: 0.8393 - val_loss: 0.5154 - val_accuracy: 0.8265
# Epoch 6/100
# 98/98 [==============================] - 8s 80ms/step - loss: 0.4357 - accuracy: 0.8061 - val_loss: 0.5099 - val_accuracy: 0.8163
# Epoch 7/100
# 98/98 [==============================] - 8s 81ms/step - loss: 0.4105 - accuracy: 0.8495 - val_loss: 0.4752 - val_accuracy: 0.8367
# Epoch 8/100
# 98/98 [==============================] - 8s 80ms/step - loss: 0.3868 - accuracy: 0.8393 - val_loss: 0.5527 - val_accuracy: 0.7959
# Epoch 9/100
# 98/98 [==============================] - 8s 81ms/step - loss: 0.4182 - accuracy: 0.8265 - val_loss: 0.4585 - val_accuracy: 0.8571
# Epoch 10/100
# 98/98 [==============================] - 8s 80ms/step - loss: 0.4454 - accuracy: 0.8240 - val_loss: 0.5632 - val_accuracy: 0.8061
# Epoch 11/100
# 98/98 [==============================] - 8s 80ms/step - loss: 0.3899 - accuracy: 0.8316 - val_loss: 0.5180 - val_accuracy: 0.7755
# Epoch 12/100
# 98/98 [==============================] - 8s 81ms/step - loss: 0.3569 - accuracy: 0.8316 - val_loss: 0.6899 - val_accuracy: 0.7245
# Epoch 13/100
# 98/98 [==============================] - 8s 80ms/step - loss: 0.3490 - accuracy: 0.8520 - val_loss: 0.5101 - val_accuracy: 0.8265
# Epoch 14/100
# 98/98 [==============================] - 8s 80ms/step - loss: 0.3202 - accuracy: 0.8724 - val_loss: 0.5106 - val_accuracy: 0.8265
# Epoch 15/100
# 98/98 [==============================] - 8s 80ms/step - loss: 0.3193 - accuracy: 0.8597 - val_loss: 0.5188 - val_accuracy: 0.8469
# Epoch 16/100
# 98/98 [==============================] - 8s 80ms/step - loss: 0.3179 - accuracy: 0.8673 - val_loss: 0.5185 - val_accuracy: 0.8367
# Epoch 17/100
# 98/98 [==============================] - 8s 80ms/step - loss: 0.3189 - accuracy: 0.8673 - val_loss: 0.5564 - val_accuracy: 0.8469
# Epoch 18/100
# 98/98 [==============================] - 8s 80ms/step - loss: 0.2863 - accuracy: 0.8724 - val_loss: 0.6067 - val_accuracy: 0.7755
# Epoch 19/100
# 98/98 [==============================] - 8s 81ms/step - loss: 0.3492 - accuracy: 0.8520 - val_loss: 0.6074 - val_accuracy: 0.7755
# 6/6 [==============================] - 2s 339ms/step - loss: 0.4388 - accuracy: 0.8232
# Mounted at /content/drive2
# EfficientNetV2B0 1
# Epoch 1/100
# 98/98 [==============================] - 19s 117ms/step - loss: 1.2281 - accuracy: 0.7500 - val_loss: 0.4247 - val_accuracy: 0.9082
# Epoch 2/100
# 98/98 [==============================] - 8s 81ms/step - loss: 0.2657 - accuracy: 0.9388 - val_loss: 0.2826 - val_accuracy: 0.9184
# Epoch 3/100
# 98/98 [==============================] - 8s 81ms/step - loss: 0.2302 - accuracy: 0.9311 - val_loss: 0.2494 - val_accuracy: 0.9388
# Epoch 4/100
# 98/98 [==============================] - 8s 80ms/step - loss: 0.2055 - accuracy: 0.9311 - val_loss: 0.2667 - val_accuracy: 0.9286
# Epoch 5/100
# 98/98 [==============================] - 8s 80ms/step - loss: 0.1837 - accuracy: 0.9388 - val_loss: 0.2177 - val_accuracy: 0.9388
# Epoch 6/100
# 98/98 [==============================] - 8s 80ms/step - loss: 0.1639 - accuracy: 0.9490 - val_loss: 0.2411 - val_accuracy: 0.9388
# Epoch 7/100
# 98/98 [==============================] - 8s 82ms/step - loss: 0.1525 - accuracy: 0.9490 - val_loss: 0.2159 - val_accuracy: 0.9490
# Epoch 8/100
# 98/98 [==============================] - 8s 80ms/step - loss: 0.1481 - accuracy: 0.9541 - val_loss: 0.2539 - val_accuracy: 0.9388
# Epoch 9/100
# 98/98 [==============================] - 8s 80ms/step - loss: 0.1859 - accuracy: 0.9413 - val_loss: 0.2740 - val_accuracy: 0.8878
# Epoch 10/100
# 98/98 [==============================] - 8s 80ms/step - loss: 0.1374 - accuracy: 0.9490 - val_loss: 0.2398 - val_accuracy: 0.9388
# Epoch 11/100
# 98/98 [==============================] - 8s 80ms/step - loss: 0.1509 - accuracy: 0.9541 - val_loss: 0.2333 - val_accuracy: 0.9388
# Epoch 12/100
# 98/98 [==============================] - 8s 80ms/step - loss: 0.1946 - accuracy: 0.9362 - val_loss: 0.3532 - val_accuracy: 0.8980
# Epoch 13/100
# 98/98 [==============================] - 8s 80ms/step - loss: 0.1670 - accuracy: 0.9439 - val_loss: 0.3360 - val_accuracy: 0.9286
# Epoch 14/100
# 98/98 [==============================] - 8s 80ms/step - loss: 0.1499 - accuracy: 0.9464 - val_loss: 0.2094 - val_accuracy: 0.9388
# Epoch 15/100
# 98/98 [==============================] - 8s 80ms/step - loss: 0.1349 - accuracy: 0.9464 - val_loss: 0.2142 - val_accuracy: 0.9388
# Epoch 16/100
# 98/98 [==============================] - 8s 81ms/step - loss: 0.1439 - accuracy: 0.9439 - val_loss: 0.1775 - val_accuracy: 0.9490
# Epoch 17/100
# 98/98 [==============================] - 8s 82ms/step - loss: 0.1389 - accuracy: 0.9490 - val_loss: 0.1925 - val_accuracy: 0.9388
# 6/6 [==============================] - 2s 339ms/step - loss: 0.1446 - accuracy: 0.9695
# Mounted at /content/drive2

# %%
before_merge = join(driveHome, "movies_to_merge")
fileNamesInSpecialOrder = ["WallPushups.avi", "BlowingCandles.avi", "CuttingInKitchen.avi", "Mixing.avi", "Swing.avi"]
video_frames_quantities = []
for fileName in fileNamesInSpecialOrder:
    video_reader = cv2.VideoCapture(join(before_merge, fileName))
    video_frames_count = int(video_reader.get(cv2.CAP_PROP_FRAME_COUNT))
    video_frames_quantities.append(video_frames_count)

    video_reader.release()

video_classes_treshold = [0 for k in range(len(fileNamesInSpecialOrder))]

for idx, frames_count in enumerate(video_frames_quantities):
    for i in range(idx, len(fileNamesInSpecialOrder)):
        video_classes_treshold[i] += frames_count

print(video_frames_quantities)
print(video_classes_treshold)
# Out:
# [68, 130, 194, 124, 151]
# [68, 198, 392, 516, 667]

# %%
def frames_counter_to_ground_truth(frameNumber):
    label = ""
    fake = False
    for idx, treshold in enumerate(video_classes_treshold):
        if frameNumber < treshold:
            label = fileNamesInSpecialOrder[idx][:-4]

            if idx > 0:
                if frameNumber < video_classes_treshold[idx-1] + 20:
                    fake = True
            else:
                if frameNumber < 20:
                    fake = True
            
            break
    
    
    return label, fake

# %%
#[68, 198, 392, 516, 667]

# %%
def predict_on_video(video_file_path, output_file_path, SEQUENCE_LENGTH, kerasModel, kerasModelName):
    resolving_frame_number = 0
    counted_frames = 0
    good_frames = 0
    is_fake = False
    video_reader = cv2.VideoCapture(video_file_path)
    original_video_width = int(video_reader.get(cv2.CAP_PROP_FRAME_WIDTH))
    original_video_height = int(video_reader.get(cv2.CAP_PROP_FRAME_HEIGHT))
    video_writer = cv2.VideoWriter(output_file_path, cv2.VideoWriter_fourcc('M', 'P', '4', 'V'), 
                                   video_reader.get(cv2.CAP_PROP_FPS), (original_video_width, original_video_height))
    frames_queue = deque(maxlen = SEQUENCE_LENGTH)
    predicted_class_name = ""
    while video_reader.isOpened():
        ok, frame = video_reader.read() 
        if not ok:
            break
        resized_frame = cv2.resize(frame, (IMAGE_HEIGHT, IMAGE_WIDTH))

        normalized_frame = resized_frame
        if not kerasModelName == "EfficientNetV2B0":
            normalized_frame = resized_frame / 255
        frames_queue.append(normalized_frame)
        if len(frames_queue) == SEQUENCE_LENGTH:
            predicted_labels_probabilities = kerasModel.predict(np.expand_dims(frames_queue, axis = 0))[0]
            predicted_label = np.argmax(predicted_labels_probabilities)
            predicted_class_name = CLASSES_LIST[predicted_label]
         
        resolving_frame_number += 1
        ground_truth, is_fake = frames_counter_to_ground_truth(resolving_frame_number)
        cv2.putText(frame, ground_truth, (10, 150), cv2.FONT_HERSHEY_COMPLEX_SMALL, 1, (0, 255, 0), 2)
        cv2.putText(frame, predicted_class_name, (10, 30), cv2.FONT_HERSHEY_COMPLEX_SMALL, 1, (0, 0, 255), 2)
        video_writer.write(frame)

        if not is_fake:
            counted_frames += 1
            if ground_truth == predicted_class_name:
                good_frames +=1

    video_reader.release()
    video_writer.release()

    return good_frames/counted_frames

# %%
moviePath = join(driveHome,"movie_to_test.mp4")
movieNewPath = os.path.basename(moviePath)
shutil.copyfile(moviePath, join(movieNewPath))
# Out:
# 'movie_to_test.mp4'

# %%
trainedModelsPath = f"{driveHome}/UCF-SmartSplit/moviesModels/"
path_forNewMovies = f"{driveHome}/UCF-SmartSplit/newMovies/"

# %%
Path(path_forNewMovies).mkdir(parents=True, exist_ok=True)
with open(join(driveHome, "UCF-SmartSplit", "GoodFrames.csv"), "w") as f: 
    f.write("model_name,ratio\n")
    for path in os.listdir(trainedModelsPath):
        modelPath = join(trainedModelsPath, path)
        kerasModel=keras.models.load_model(modelPath)
        modelName = re.search("EfficientNetV2B0|InceptionV3|MobileNetV2", path).group()
        print(modelName)
        output_video_file_path = f"{path_forNewMovies}{path}-Output.mp4"
        good_to_bad_ratio = predict_on_video(movieNewPath, output_video_file_path, SEQUENCE_LENGTH, kerasModel, modelName)
        f.write(f"{path},{good_to_bad_ratio}\n")

flushDrive()
# Out:
# InceptionV3

# %%
def get_images_examples(video_file_path, output_file_path):
    Path(output_file_path).mkdir(parents=True, exist_ok=True)
    video_reader = cv2.VideoCapture(video_file_path)
    wanted_frames = [65, 199, 490, 640]
    for frame_count in wanted_frames:
        video_reader.set(cv2.CAP_PROP_POS_FRAMES, frame_count)
        ok, frame = video_reader.read() 
        if not ok:
            break

        wrote = cv2.imwrite(join(output_file_path, str(frame_count) + ".jpg"), frame)
        if not wrote:
            print("Sth went wrong")

    video_reader.release()

# %%
video_file_path=os.listdir(path_forNewMovies)[1]
video_file_path = join(path_forNewMovies, video_file_path)
output_file_path=f"{driveHome}/UCF-SmartSplit/classifiedFrames/"
get_images_examples(video_file_path, output_file_path)

# %%
flushDrive()
